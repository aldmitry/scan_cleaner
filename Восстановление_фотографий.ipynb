# %%
from tensorflow.keras.models import Model, Sequential 
from tensorflow.keras.layers import Dense, Flatten, Reshape, Input, Conv2DTranspose, concatenate, Activation, MaxPooling2D, Conv2D, BatchNormalization,Dropout, Conv1D, Conv1DTranspose, MaxPooling1D
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import utils
from tensorflow.keras.datasets import mnist, fashion_mnist
from tensorflow.keras.callbacks import LambdaCallback, ModelCheckpoint
from keras.models import load_model
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image
import numpy as np
import pandas as pd
from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import os
from google.colab import drive
import time, random
import seaborn as sns
import random
sns.set_style('darkgrid')

# %%
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# # Модель удаляет черные пятна с фотографий, восстанавливая их

# %% [markdown]
# #Предобработка и загрузка базы

# %%
# !unzip -q '/content/drive/MyDrive/Базы/Лица.zip' # распоковываем базу с лицами с google диска в colaboratory

# %%
images_dir = 'Лица' # зададим имя папки в которую распоковали изображения
img_height = 112 # зададим высоту изображений
img_width = 80 # зададим ширину избражений

# функция загрузки изображений, на вход принемает имя папки с изображениями, высоту и ширину к которой будут преобразованы загружаемые изображения
def load_images(images_dir, img_height, img_width): 
  
  list_images = [] 
  new_images = []
  for img in os.listdir(images_dir): 
      a = random.randint(0, 60) #высота прямоугольника
      b = random.randint(0, 40) #Ширина прямоугольника
      x1,x2 = random.randint(2, 60),random.randint(2, 40) #Верхний левый угол прфямоугольника
      t = image.img_to_array(image.load_img(os.path.join(images_dir, img), target_size=(img_height, img_width), color_mode='grayscale'))
      t1 = t.copy()
      t1[x1:x1+a, x2:x2+b] = 0

    
      list_images.append(t)
      new_images.append(t1)
  return np.array(list_images), np.array(new_images)

# %%
xTrain_imag, xTrain_imag1 = load_images(images_dir, img_height, img_width) # загрузим избражения лиц

xTrain_img = xTrain_imag/255
xTrain_img1 = xTrain_imag1/255

print(xTrain_img.shape)
print(xTrain_img1.shape)
# Out:
# (5018, 112, 80, 1)
# (5018, 112, 80, 1)

# %%
plt.imshow(xTrain_img[np.random.randint(0, xTrain_img.shape[0])].reshape(112,80), cmap='gray') #выведем случайное изображение
plt.show()

# %%
noisedXTrainFace = xTrain_img1

# %%
def plotImages(xTrain, pred, shape=(112, 80)): # создадим функцию для вывода изображений как картинок
  n = 5  # количество картинок, которые хотим показать
  plt.figure(figsize=(14, 7)) # указываем размеры фигуры
  for i in range(n): # для каждой картинки из n(5)
      index = np.random.randint(0, pred.shape[0]) # startIndex - начиная с какого индекса хотим заплотить картинки
      # Показываем картинки из тестового набора
      ax = plt.subplot(2, n, i + 1) # выведем область рисования Axes
      plt.imshow(xTrain[index].reshape(shape)) # отрисуем правильные картинки в размере 112*80      
      plt.gray() # выведем в черно-белом цвете
      ax.get_xaxis().set_visible(False) # скрываем вывод координатной оси x
      ax.get_yaxis().set_visible(False) # скрываем вывод координатной оси y

      # Показываем восстановленные картинки
      ax = plt.subplot(2, n, i + 1 + n) # выведем область рисования Axes 
      plt.imshow(pred[index].reshape(shape)) # отрисуем обработанные сеткой картинки в размере 112*80     
      plt.gray() # выведем в черно-белом цвете
      ax.get_xaxis().set_visible(False) # скрываем вывод координатной оси x
      ax.get_yaxis().set_visible(False) # скрываем вывод координатной оси y
  plt.show()

# %%
plotImages(xTrain_img, noisedXTrainFace) # выведем на экран исходные лица и зашумленные варианты

# %% [markdown]
# #Автокодировщик №2

# %%
def denoiseAutoencoder(): # объявляем функцию создания автокодировщика для подавления шума
    img_input = Input((112,80,1)) # задаём входные размеры

    x = Conv2D(64, (3, 3), padding='same', activation='relu')(img_input) # входные данные передаем на слой двумерной свёртки
    x = BatchNormalization()(x) # затем пропускаем через слой нормализации данных 
    x = Conv2D(64, (3, 3), padding='same', activation='relu')(x) # далее снова слой двумерной свёртки
    x = BatchNormalization()(x) # и еще слой нормализации данных
    x = MaxPooling2D()(x) # передаём на слой подвыборки, снижающий размерность поступивших на него данных

    x = Conv2D(128, (3, 3), padding='same', activation='relu')(x) # передаем на слой двумерной свёртки
    x = BatchNormalization()8, (3, 3)(x) # пропускаем через слой нормализации данных 
    x = Conv2D(12, padding='same', activation='relu')(x)  # далее снова слой двумерной свёртки
    x = BatchNormalization()(x) # и еще слой нормализации данных
    z = MaxPooling2D()(x) # передаём на слой подвыборки
    

    x = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same', activation='relu')(z) # слой разжимает данные(с 28*20 на 56*40)
    x = BatchNormalization()(x) # слой нормализации данных
    
    x = Conv2D(128, (3, 3), padding='same', activation='relu')(x) 
    x = BatchNormalization()(x) 
    x = Conv2D(128, (3, 3), padding='same', activation='relu')(x) 
    x = BatchNormalization()(x)
    # Сжатие MaxPooling2D не применяем

    x = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same', activation='relu')(x) # слой разжимает данные(с 56*40 на 112*80)
    x = BatchNormalization()(x) 
    x = Conv2D(64, (3, 3), padding='same', activation='relu')(x) 
    x = BatchNormalization()(x)
    x = Conv2D(64, (3, 3), padding='same', activation='relu')(x) 
    x = BatchNormalization()(x) 

    # Финальный слой двумерной свертки, выдающий итоговое изображение
    x = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

    model = Model(img_input, x) # собрали модель с зашумленной картинкой на вход и с очищенной от шума на выход
    model.compile(optimizer='adam',
                  loss='mse') # компилируем модель также, с выбором оптимайзера и среднеквадратичной ошибки

    return model # функция вернет модель подавления шума



modelDenoiseFace = denoiseAutoencoder()
modelDenoiseFace.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 112, 80, 1)]      0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 112, 80, 64)       640
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 112, 80, 64)       256
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 112, 80, 64)       36928
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 112, 80, 64)       256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 56, 40, 64)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 56, 40, 128)       73856
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 56, 40, 128)       512
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 56, 40, 128)       147584
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 56, 40, 128)       512
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 28, 20, 128)       0
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 56, 40, 128)       65664
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 56, 40, 128)       512
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 56, 40, 128)       147584
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 56, 40, 128)       512
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 56, 40, 128)       147584
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 56, 40, 128)       512
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 112, 80, 64)       32832
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 112, 80, 64)       256
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 112, 80, 64)       36928
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 112, 80, 64)       256
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 112, 80, 64)       36928
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 112, 80, 64)       256
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 112, 80, 1)        577
# =================================================================
# Total params: 730,945
# Trainable params: 729,025
# Non-trainable params: 1,920
# _________________________________________________________________

# %%
modelDenoiseFace = denoiseAutoencoder()
# Подаем на вход зашумленные картинки, а на выход правильные, исходные картинки, и обучаем
best__loss = ModelCheckpoint('best_loss.h5', save_best_only=True, monitor='val_loss', mode='min')
history = modelDenoiseFace.fit(noisedXTrainFace[:4700], xTrain_img[:4700], epochs=30, batch_size=100, validation_data = (noisedXTrainFace[4700:], xTrain_img[4700:]), callbacks=[best__loss])
# Out:
# Epoch 1/30
# 47/47 [==============================] - 20s 401ms/step - loss: 0.0329 - val_loss: 0.0615
# Epoch 2/30
# 47/47 [==============================] - 19s 407ms/step - loss: 0.0059 - val_loss: 0.0590
# Epoch 3/30
# 47/47 [==============================] - 19s 397ms/step - loss: 0.0051 - val_loss: 0.0547
# Epoch 4/30
# 47/47 [==============================] - 19s 394ms/step - loss: 0.0045 - val_loss: 0.0544
# Epoch 5/30
# 47/47 [==============================] - 19s 395ms/step - loss: 0.0041 - val_loss: 0.0487
# Epoch 6/30
# 47/47 [==============================] - 19s 398ms/step - loss: 0.0042 - val_loss: 0.0467
# Epoch 7/30
# 47/47 [==============================] - 19s 396ms/step - loss: 0.0042 - val_loss: 0.0404
# Epoch 8/30
# 47/47 [==============================] - 19s 396ms/step - loss: 0.0035 - val_loss: 0.0393
# Epoch 9/30
# 47/47 [==============================] - 19s 396ms/step - loss: 0.0034 - val_loss: 0.0360
# Epoch 10/30
# 47/47 [==============================] - 19s 395ms/step - loss: 0.0035 - val_loss: 0.0255
# Epoch 11/30
# 47/47 [==============================] - 19s 396ms/step - loss: 0.0035 - val_loss: 0.0237
# Epoch 12/30
# 47/47 [==============================] - 19s 396ms/step - loss: 0.0033 - val_loss: 0.0152
# Epoch 13/30
# 47/47 [==============================] - 19s 396ms/step - loss: 0.0033 - val_loss: 0.0123
# Epoch 14/30
# 47/47 [==============================] - 19s 396ms/step - loss: 0.0031 - val_loss: 0.0134
# Epoch 15/30
# 47/47 [==============================] - 19s 396ms/step - loss: 0.0030 - val_loss: 0.0070
# Epoch 16/30
# 47/47 [==============================] - 19s 397ms/step - loss: 0.0032 - val_loss: 0.0051
# Epoch 17/30
# 47/47 [==============================] - 19s 396ms/step - loss: 0.0031 - val_loss: 0.0047
# Epoch 18/30
# 47/47 [==============================] - 19s 396ms/step - loss: 0.0029 - val_loss: 0.0051
# Epoch 19/30
# 47/47 [==============================] - 19s 397ms/step - loss: 0.0028 - val_loss: 0.0043
# Epoch 20/30
# 47/47 [==============================] - 19s 396ms/step - loss: 0.0028 - val_loss: 0.0033
# Epoch 21/30
# 47/47 [==============================] - 19s 396ms/step - loss: 0.0032 - val_loss: 0.0051
# Epoch 22/30
# 47/47 [==============================] - 19s 396ms/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 23/30
# 47/47 [==============================] - 19s 396ms/step - loss: 0.0030 - val_loss: 0.0026
# Epoch 24/30
# 47/47 [==============================] - 19s 396ms/step - loss: 0.0027 - val_loss: 0.0039
# Epoch 25/30
# 47/47 [==============================] - 19s 395ms/step - loss: 0.0027 - val_loss: 0.0033
# Epoch 26/30
# 47/47 [==============================] - 19s 396ms/step - loss: 0.0026 - val_loss: 0.0043
# Epoch 27/30
# 47/47 [==============================] - 19s 396ms/step - loss: 0.0028 - val_loss: 0.0047
# Epoch 28/30
# 47/47 [==============================] - 19s 396ms/step - loss: 0.0025 - val_loss: 0.0031
# Epoch 29/30
# 47/47 [==============================] - 19s 396ms/step - loss: 0.0026 - val_loss: 0.0027
# Epoch 30/30
# 47/47 [==============================] - 19s 395ms/step - loss: 0.0026 - val_loss: 0.0030

# %%
#Выводим графики
plt.figure(figsize=(14,7))
plt.plot(history.history['loss'][10:], 
         label='Средняя абсолютная ошибка на обучающем наборе')
plt.plot(history.history['val_loss'][10:], 
         label='Средняя абсолютная ошибка на проверочном наборе')
plt.ylabel('Средняя ошибка')
plt.legend()
plt.show()

# %%
modelDenoiseFace = load_model('/content/best_loss.h5')

# %%
modelDenoiseFace.compile(optimizer=Adam(lr=1e-4), loss='mse')
history = modelDenoiseFace.fit(noisedXTrainFace[:4700], xTrain_img[:4700], epochs=30, batch_size=100, validation_data = (noisedXTrainFace[4700:], xTrain_img[4700:]), callbacks=[best__loss])
# Out:
# Epoch 1/30
# 47/47 [==============================] - 19s 383ms/step - loss: 0.0026 - val_loss: 0.0037
# Epoch 2/30
# 47/47 [==============================] - 18s 379ms/step - loss: 0.0025 - val_loss: 0.0026
# Epoch 3/30
# 47/47 [==============================] - 18s 388ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 4/30
# 47/47 [==============================] - 18s 389ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 5/30
# 47/47 [==============================] - 18s 389ms/step - loss: 0.0024 - val_loss: 0.0032
# Epoch 6/30
# 47/47 [==============================] - 18s 391ms/step - loss: 0.0024 - val_loss: 0.0026
# Epoch 7/30
# 47/47 [==============================] - 19s 395ms/step - loss: 0.0024 - val_loss: 0.0031
# Epoch 8/30
# 47/47 [==============================] - 19s 396ms/step - loss: 0.0023 - val_loss: 0.0037
# Epoch 9/30
# 47/47 [==============================] - 19s 396ms/step - loss: 0.0024 - val_loss: 0.0027
# Epoch 10/30
# 47/47 [==============================] - 19s 395ms/step - loss: 0.0024 - val_loss: 0.0043
# Epoch 11/30
# 47/47 [==============================] - 19s 395ms/step - loss: 0.0024 - val_loss: 0.0027
# Epoch 12/30
# 47/47 [==============================] - 19s 396ms/step - loss: 0.0023 - val_loss: 0.0030
# Epoch 13/30
# 47/47 [==============================] - 19s 395ms/step - loss: 0.0024 - val_loss: 0.0027
# Epoch 14/30
# 47/47 [==============================] - 19s 396ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 15/30
# 47/47 [==============================] - 19s 395ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 16/30
# 47/47 [==============================] - 19s 396ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 17/30
# 47/47 [==============================] - 19s 395ms/step - loss: 0.0023 - val_loss: 0.0026
# Epoch 18/30
# 47/47 [==============================] - 19s 395ms/step - loss: 0.0022 - val_loss: 0.0023
# Epoch 19/30
# 47/47 [==============================] - 19s 396ms/step - loss: 0.0023 - val_loss: 0.0026
# Epoch 20/30
# 47/47 [==============================] - 19s 396ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 21/30
# 47/47 [==============================] - 19s 395ms/step - loss: 0.0022 - val_loss: 0.0023
# Epoch 22/30
# 47/47 [==============================] - 19s 396ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 23/30
# 47/47 [==============================] - 19s 396ms/step - loss: 0.0023 - val_loss: 0.0031
# Epoch 24/30
# 47/47 [==============================] - 19s 395ms/step - loss: 0.0022 - val_loss: 0.0024
# Epoch 25/30
# 47/47 [==============================] - 19s 396ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 26/30
# 47/47 [==============================] - 19s 396ms/step - loss: 0.0023 - val_loss: 0.0025
# Epoch 27/30
# 47/47 [==============================] - 19s 396ms/step - loss: 0.0023 - val_loss: 0.0026
# Epoch 28/30
# 47/47 [==============================] - 19s 395ms/step - loss: 0.0023 - val_loss: 0.0026
# Epoch 29/30
# 47/47 [==============================] - 19s 396ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 30/30
# 47/47 [==============================] - 19s 396ms/step - loss: 0.0021 - val_loss: 0.0031

# %%
modelDenoiseFace = load_model('/content/best_loss.h5')

# %%
modelDenoiseFace.compile(optimizer=Adam(lr=1e-5), loss='mse')
history = modelDenoiseFace.fit(noisedXTrainFace[:4700], xTrain_img[:4700], epochs=1, batch_size=100, validation_data = (noisedXTrainFace[4700:], xTrain_img[4700:]))
# Out:
# 47/47 [==============================] - 19s 387ms/step - loss: 0.0022 - val_loss: 0.0022

# %%
predTrain = modelDenoiseFace.predict(noisedXTrainFace[:4700]) 
predTrain = predTrain * 255 # представляем в виде значений от 0 до 255
predTrain = predTrain.astype('uint8') # устанавливаем 8битовый тип

plotImages(noisedXTrainFace[:4700], predTrain, shape=(112,80))

# %%
predTest = modelDenoiseFace.predict(noisedXTrainFace[4700:]) 
predTest = predTest * 255 # представляем в виде значений от 0 до 255
predTest = predTest.astype('uint8') # устанавливаем 8битовый тип
plotImages(noisedXTrainFace[4700:], predTest, shape=(112,80))

# %%
err_Train = [getMSE(xTrain_img[:4700][i], predTrain[i] / 255) for i in range(len(predTrain))]# Возьмем среднеквадратичную ошибку от правильной картинки, и восстановленной, пройдя по 12тыс изображений
err_Test = [getMSE(xTrain_img[4700:][i], predTest[i] / 255) for i in range(len(predTest))]# Возьмем среднеквадратичную ошибку от правильной картинки, и восстановленной, пройдя по 12тыс изображений
print("Средняя ошибка на обучающем наборе :", sum(err_Train) / xTrain_img[:4700].shape[0]) # взглянем на среднюю ошибку на обучающей выборке
print("Средняя ошибка на тестовом наборе:", sum(err_Test) /xTrain_img[4700:].shape[0] ) # и на проверочной выборке
# Out:
# Средняя ошибка на обучающем наборе MNIST: 0.0023318843239799056
# Средняя ошибка на тестовом наборе MNIST: 0.002470525431182502

# %% [markdown]
# # Мелкие помехи успешно восстанавливаются, крупне сложнее. Возможно следует увеличить базу раза в 3 и усложнить сетку, либо сделать совокупность сеток
